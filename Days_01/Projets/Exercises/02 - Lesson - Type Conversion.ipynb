# %% [markdown]
# <a href="https://colab.research.google.com/github/yahia-kplr/Fondamentaux-Python-1/blob/main/Days_01/Projets/Exercises/02%20-%20Lesson%20-%20Type%20Conversion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Type Conversion
# - More about formatted strings
# - Types are not the same
# - Convert them with **int(), float(), str()**
